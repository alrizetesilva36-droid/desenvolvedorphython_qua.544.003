# %%
nome = "Alrizete Almeida"
texto = f"Esta é uma célula Python escrita pela melhor programadora de todos os tempos: {nome} 😉"

print(texto)
# Out:
# Esta é uma célula Python escrita pela melhor programadora de todos os tempos: Alrizete Almeida 😉

# %% [markdown]
# A célula de Python também perminte códigos de entrada de dados. Veja:

# %% [markdown]
# As células Python são acumulativas, e reconhecem as variáveis das células anterionres:
#
# Observe, por exemplo, a célula abaixo:

# %%
nome = input("Informe seu nome: ").strip().title()
print(nome)

# %%
n1 = 5
print(f"O valor da variável 'n1' é {n1}. ")

# %% [markdown]
# O valor de n1 é claramente 5. Porém, veja na próxima celula e diga qual será o valor da variável result:

# %%
result = 15 + n1
print(result)

# %% [markdown]
# O valor de result é 20, pois está somando 15 com n1, que tinha o valor de 5.
#
#
# Mas agora observe a célula abaixo sem executá-la:

# %%
 x = 10

# %% [markdown]
# Agora, faça o código abaixo na próxima célula, execute e veja qual é o resultado:

# %%
result = 25 + x
print(result)

# %% [markdown]
# # Aula do dia 04/09/2026
#
# Hoje, iremos aprender a trabalhar com células Python. As células Python executam códigos Python dentro dos notebooks.
# Observe a célula Python abaixo:
