# %% [markdown]
# # Titulo do meu documento
#
# Nesta aula iremos aprender cobre como inserir ***markdowns*** dentro de arquivos do tipo **Jupyter Notebook**.
#
#
# >***Markdaown*** é um tipo de documento muito usado em ciência de dados  e tambem para alimentar Inteligência Artificial.
# >
# >Manipular este tipo de arquivo se torna fundamental para dominar as profissões de futuro que dependem de IAs.

# %% [markdown]
# ## Subtitulo de markdown
#
# o que diferencia um markdown de um notebook. é  que no caso do notebook, ele também é capaz de ler  códigos da s linguagens de programação *R*, *Julia*, e é claro, Python.

# %% [markdown]
# ## Checklist
#
# ### Linguagens de programação aceitas em notebooks
#
# ✅Python<br>
# ✅Julia<br>
# ✅R<br>
#
#
# ### Linguagens que iremos utilizar no curso
#
# ✅Python<br>
# ❌Julia<br>
# ❌R<br>
